# %%
import pandas as pd
import datetime
import numpy as np

import matplotlib.pyplot as plt
import subprocess #ベクター画像出力用

import matplotlib.dates as mdates # DataTimeの横軸調整

# %%
# matplotlibの設定

plt.rcParams['font.size'] = 10
plt.rcParams['font.family']= 'sans-serif'
plt.rcParams['font.sans-serif'] = ['Arial']

plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.rcParams['xtick.major.width'] = 1
plt.rcParams['ytick.major.width'] = 1
plt.rcParams['xtick.major.size'] = 5
plt.rcParams['ytick.major.size'] = 5
plt.rcParams['axes.linewidth'] = 1
plt.rcParams['axes.grid'] = False
plt.rcParams['grid.linestyle']='--'
plt.rcParams['grid.linewidth'] = 0.3

plt.rcParams["xtick.minor.visible"] = True # x軸副目盛り線を描くかどうか
plt.rcParams["ytick.minor.visible"] = True # y軸副目盛り線を描くかどうか
plt.rcParams["xtick.minor.size"] = 3.0      # x軸副目盛り線の長さ
plt.rcParams["ytick.minor.size"] = 3.0      # y軸副目盛り線の長さ
plt.rcParams["xtick.minor.width"] = 0.6     # x軸副目盛り線の線幅
plt.rcParams["ytick.minor.width"] = 0.6     # y軸副目盛り線の線幅

plt.rcParams["legend.markerscale"] = 1.5
plt.rcParams["legend.fancybox"] = False
plt.rcParams["legend.framealpha"] = 1
plt.rcParams["legend.edgecolor"] = 'black'

# %%
def time_change(x):
    dt2 = dt1 + datetime.timedelta(seconds=x)
    return dt2
# dft = pd.read_csv('PoolTEMP_20220315.csv', header=11)
# dt1 = datetime.datetime(2022, 2, 14, 16, 48, 3)
dft = pd.read_csv('PoolTEMP_20221222.csv', header=11)
dt1 = datetime.datetime(2022, 12, 21, 16, 9, 10)
dft['Time'] = dft['Time'].apply(time_change)
dft = dft.set_index('Time', drop=True) # 引数drop=Falseとすると、指定列がindexに設定された上でデータ列にもそのまま残る。

#figure()でグラフを表示する領域をつくり，figというオブジェクトにする．
fig = plt.figure(figsize=(10,3), dpi=120, facecolor='w')

#add_subplot()でグラフを描画する領域を追加する．引数は行，列，場所
ax1 = fig.add_subplot(1, 1, 1)

ax1.plot(dft.index, dft["R1-1[C]"], c='black',linewidth=0.7)
ax1.plot(dft.index, dft["R1-2[C]"], c='blue',linewidth=0.7)
ax1.plot(dft.index, dft["R1-3[C]"], c='green',linewidth=0.7)
ax1.plot(dft.index, dft["R1-4[C]"], c='red',linewidth=0.7)
ax1.plot(dft.index, dft["R1-5[C]"], c='red',linewidth=0.7)
ax1.plot(dft.index, dft["R1-6[C]"], c='red',linewidth=0.7)
ax1.plot(dft.index, dft["R1-7[C]"], c='red',linewidth=0.7)
ax1.plot(dft.index, dft["R1-8[C]"], c='red',linewidth=0.7)
ax1.plot(dft.index, dft["R1-9[C]"], c='red',linewidth=0.7)
ax1.plot(dft.index, dft["R1-10[C]"], c='red',linewidth=0.7)
ax1.plot(dft.index, dft["R1-11[C]"], c='red',linewidth=0.7)
ax1.plot(dft.index, dft["R1-12[C]"], c='red',linewidth=0.7)
ax1.plot(dft.index, dft["R1-13[C]"], c='red',linewidth=0.7)
ax1.plot(dft.index, dft["R1-14[C]"], c='red',linewidth=0.7)
ax1.plot(dft.index, dft["R1-15[C]"], c='red',linewidth=0.7)

ax1.legend(["U1-1[C]","U1-11[C]","U1-13[C]","U1-14[C]","U1-15[C]"])

#ax1.set_title('temperature')
#ax1.set_xlabel('')
ax1.set_ylabel('Temperature [deg]')

name = "20220204_気温"

plt.show()
dft
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 6
#       3     return dt2
#       4 # dft = pd.read_csv('PoolTEMP_20220315.csv', header=11)
#       5 # dt1 = datetime.datetime(2022, 2, 14, 16, 48, 3)
# ----> 6 dft = pd.read_csv('PoolTEMP_20221222.csv', header=11)
#       7 dt1 = datetime.datetime(2022, 12, 21, 16, 9, 10)
#       8 dft['Time'] = dft['Time'].apply(time_change)
#
# File C:\Users\seppyo-kagaku_5\Desktop\v1\python-3.8.2-embed-amd64\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# ...

# %%
y = np.array((4,2,0,-2,-4,-6,-8,-10,-12,-14,-16,-21,-26,-36,-46))
y

# %%
dft_size = dft.shape
dft_size

# %%
list(range(15))

# %%
Z = np.zeros((dft_size[0], dft_size[1]-1))
Z.shape

# %%
for i in range(15):
    Z[:,i] = dft.iloc[:,i]
Z

# %%
Z.shape

# %%
Z = Z.T
Z.shape

# %%
#figure()でグラフを表示する領域をつくり，figというオブジェクトにする．
fig = plt.figure(figsize=(10,3), dpi=120, facecolor='w')

#add_subplot()でグラフを描画する領域を追加する．引数は行，列，場所
ax1 = fig.add_subplot(1, 1, 1)

# ax1.contour(dft.index, y, Z, 15,colors='black')  
c = ax1.contourf(dft.index, y, Z, 15, cmap="jet") 
# ax1.invert_yaxis()
fig.colorbar(c)
dft.index, dft["R1-1[C]"]


#ax1.set_title('temperature')
#ax1.set_xlabel('')
ax1.set_ylabel('hight [cm]')

name = "20220204_気温"

plt.show()

# %%
#figure()でグラフを表示する領域をつくり，figというオブジェクトにする．
fig = plt.figure(figsize=(10,3), dpi=120, facecolor='w')

#add_subplot()でグラフを描画する領域を追加する．引数は行，列，場所
ax1 = fig.add_subplot(1, 1, 1)

# ax1.contour(dft.index, y, Z, 15,colors='black')  
c = ax1.contourf(dft.index, y, Z, 15, cmap="jet") 
# ax1.invert_yaxis()
fig.colorbar(c)
dft.index, dft["R1-1[C]"]


#ax1.set_title('temperature')
#ax1.set_xlabel('')
ax1.set_ylabel('height (cm)')

ax1.set_ylim(-46,4)

name = "20220204_気温"

plt.show()

# %%
def time_change(x):
    dt2 = dt1 + datetime.timedelta(seconds=x)
    return dt2
dft = pd.read_csv('PoolTEMP_20220323.csv', header=11)
dt1 = datetime.datetime(2022, 3, 18, 11, 54, 53)
dft['Time'] = dft['Time'].apply(time_change)

#figure()でグラフを表示する領域をつくり，figというオブジェクトにする．
fig = plt.figure(figsize=(10,3), dpi=120, facecolor='w')

#add_subplot()でグラフを描画する領域を追加する．引数は行，列，場所
ax1 = fig.add_subplot(1, 1, 1)

ax1.plot(dft.index, dft["U1-1[C]"], c='#d70035',linewidth=0.7)


ax1.legend(["U1-1[C]","U1-11[C]","U1-13[C]","U1-14[C]","U1-15[C]"])

#ax1.set_title('temperature')
#ax1.set_xlabel('')
ax1.set_ylabel('Temperature [deg]')

name = "20220204_気温"

plt.show()
dft

# %%
def time_change(x):
    dt2 = dt1 + datetime.timedelta(seconds=x)
    return dt2
dft = pd.read_csv('PoolTEMP_20220311_dummy.csv', header=11)
dt1 = datetime.datetime(2022, 3, 11, 10, 47, 3)
dft['Time'] = dft['Time'].apply(time_change)

#figure()でグラフを表示する領域をつくり，figというオブジェクトにする．
fig = plt.figure(figsize=(10,3), dpi=120, facecolor='w')

#add_subplot()でグラフを描画する領域を追加する．引数は行，列，場所
ax1 = fig.add_subplot(1, 1, 1)

ax1.plot(dft.index, dft["U1-1[C]"], c='#d70035',linewidth=0.7)


ax1.legend(["U1-1[C]","U1-11[C]","U1-13[C]","U1-14[C]","U1-15[C]"])

#ax1.set_title('temperature')
#ax1.set_xlabel('')
ax1.set_ylabel('Temperature [deg]')

name = "20220204_気温"

plt.show()
dft

# %%
df1 = pd.read_csv('PoolTEMP_20220126.csv', header=11)
df2 = pd.read_csv('PoolTEMP_20220204.csv', header=11)
df3 = pd.read_csv('PoolTEMP_20220205.csv', header=11)
df4 = pd.read_csv('PoolTEMP_20220214.csv', header=11)
df5 = pd.read_csv('PoolTEMP_20220315.csv', header=11)
df6 = pd.read_csv('PoolTEMP_20220323.csv', header=11)
df7 = pd.read_csv('PoolTEMP_20220328.csv', header=11)
df8 = pd.read_csv('PoolTEMP_20220311_dummy.csv', header=11)
df9 = pd.read_csv('PoolTEMP_20220413.csv', header=11)
df10 = pd.read_csv('PoolTEMP_20220422.csv', header=11)
df11 = pd.read_csv('PoolTEMP_20220425.csv', header=11)
df12 = pd.read_csv('PoolTEMP_20220427.csv', header=11)
df13 = pd.read_csv('PoolTEMP_20220501.csv', header=11)
df14 = pd.read_csv('PoolTEMP_20220511.csv', header=11)
def time_change(x):
    dt2 = dt1 + datetime.timedelta(seconds=x)
    return dt2
dt1 = datetime.datetime(2022, 1, 19, 11, 28, 23)
df1['Time'] = df1['Time'].apply(time_change)
dt1 = datetime.datetime(2022, 1, 26, 14, 39, 33)
df2['Time'] = df2['Time'].apply(time_change)
dt1 = datetime.datetime(2022, 2, 4, 11, 24, 5)
df3['Time'] = df3['Time'].apply(time_change)
dt1 = datetime.datetime(2022, 2, 5, 12, 54, 28)
df4['Time'] = df4['Time'].apply(time_change)
dt1 = datetime.datetime(2022, 2, 14, 16, 48, 3)
df5['Time'] = df5['Time'].apply(time_change)
dt1 = datetime.datetime(2022, 3, 18, 11, 54, 53)
df6['Time'] = df6['Time'].apply(time_change)
dt1 = datetime.datetime(2022, 3, 23, 11, 24, 31)
df7['Time'] = df7['Time'].apply(time_change)
dt1 = datetime.datetime(2022, 3, 11, 10, 48, 3)
df8['Time'] = df8['Time'].apply(time_change)
dt1 = datetime.datetime(2022, 3, 28, 10, 42, 18)
df9['Time'] = df9['Time'].apply(time_change)
dt1 = datetime.datetime(2022, 4, 13, 15, 47, 54)
df10['Time'] = df10['Time'].apply(time_change)
dt1 = datetime.datetime(2022, 4, 22, 18, 4, 34)
df11['Time'] = df11['Time'].apply(time_change)
dt1 = datetime.datetime(2022, 4, 25, 10, 25, 27)
df12['Time'] = df12['Time'].apply(time_change)
dt1 = datetime.datetime(2022, 4, 27, 12, 16, 14)
df13['Time'] = df13['Time'].apply(time_change)
dt1 = datetime.datetime(2022, 5, 6, 14, 45, 31)
df14['Time'] = df14['Time'].apply(time_change)
df1 = df1.set_index('Time', drop=True) # 引数drop=Falseとすると、指定列がindexに設定された上でデータ列にもそのまま残る。
df2 = df2.set_index('Time', drop=True) # 引数drop=Falseとすると、指定列がindexに設定された上でデータ列にもそのまま残る。
df3 = df3.set_index('Time', drop=True) # 引数drop=Falseとすると、指定列がindexに設定された上でデータ列にもそのまま残る。
df4 = df4.set_index('Time', drop=True) # 引数drop=Falseとすると、指定列がindexに設定された上でデータ列にもそのまま残る。
df5 = df5.set_index('Time', drop=True) # 引数drop=Falseとすると、指定列がindexに設定された上でデータ列にもそのまま残る。
df6 = df6.set_index('Time', drop=True) # 引数drop=Falseとすると、指定列がindexに設定された上でデータ列にもそのまま残る。
df7 = df7.set_index('Time', drop=True) # 引数drop=Falseとすると、指定列がindexに設定された上でデータ列にもそのまま残る。
df8 = df8.set_index('Time', drop=True) # 引数drop=Falseとすると、指定列がindexに設定された上でデータ列にもそのまま残る。
df9 = df9.set_index('Time', drop=True) # 引数drop=Falseとすると、指定列がindexに設定された上でデータ列にもそのまま残る。
df10 = df10.set_index('Time', drop=True) # 引数drop=Falseとすると、指定列がindexに設定された上でデータ列にもそのまま残る。
df11 = df11.set_index('Time', drop=True) # 引数drop=Falseとすると、指定列がindexに設定された上でデータ列にもそのまま残る。
df12 = df12.set_index('Time', drop=True) # 引数drop=Falseとすると、指定列がindexに設定された上でデータ列にもそのまま残る。
df13 = df13.set_index('Time', drop=True) # 引数drop=Falseとすると、指定列がindexに設定された上でデータ列にもそのまま残る。
df14 = df14.set_index('Time', drop=True) # 引数drop=Falseとすると、指定列がindexに設定された上でデータ列にもそのまま残る。

# df1 = df1.resample('min').interpolate() # 線形補完
# df2 = df2.resample('s').interpolate() # 線形補完

df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14])

# df = df.asfreq('10min') # リサンプル
df = df.resample('s').interpolate() # 線形補完
df = df.resample('10min').interpolate() # 線形補完

df = df.drop(df.index[[0]], axis=0)

df.to_csv('output/temp.csv')

df

# %%
# df = pd.read_csv('output/temp.csv', header=0)
# df = df.set_index('Time')
# df

# %%
#figure()でグラフを表示する領域をつくり，figというオブジェクトにする．
fig = plt.figure(figsize=(10,3), dpi=120, facecolor='w')

#add_subplot()でグラフを描画する領域を追加する．引数は行，列，場所
ax1 = fig.add_subplot(1, 1, 1)

ax1.plot(df.index, df["U1-1[C]"], c='#d70035',linewidth=0.7)
ax1.plot(df.index, df["U1-11[C]"], c='black',linewidth=0.7)
ax1.plot(df.index, df["U1-13[C]"], c='#0000ff',linewidth=0.7)
ax1.plot(df.index, df["U1-14[C]"], c='#00885a',linewidth=0.7)
ax1.plot(df.index, df["U1-15[C]"], c='#8a2be2',linewidth=0.7)

ax1.legend(["U1-1[C]","U1-11[C]","U1-13[C]","U1-14[C]","U1-15[C]"])

#ax1.set_title('temperature')
#ax1.set_xlabel('')
ax1.set_ylabel('Temperature [deg]')

name = "20220204_気温"

plt.show()

plt.savefig(f'graph/{name}.png')
plt.savefig(f'graph/{name}.svg')
subprocess.call(f'inkscape graph/{name}.svg -M graph/{name}.emf', shell=True)

# %%
import importlib
# importlib.reload(solve) # importの更新
# importlib.reload(stefanbudget) # importの更新

import solve
import stefanbudget

Ta_df = df.iloc[:,10]
Ta = Ta_df.values.tolist()
le = len(Ta)

hs = []
for i in range(le):
    hs.append(0)
    
InputData = [0, Ta, hs]

hio = 0.21

hi = solve.SolveHi(InputData)
df['hi'] = np.array(hi)*100

histefan = stefanbudget.SolveHi(InputData)
df['hi(stefan)'] = np.array(histefan)*100

# df.to_csv('output/20220204.csv')

df

# %%
import importlib
importlib.reload(solve) # importの更新
importlib.reload(stefanbudget) # importの更新

import solve
import stefanbudget

histefan = stefanbudget.SolveHi(InputData)
df['hi(stefan 0.68)'] = np.array(histefan)*100

df.to_csv('output/20221125.csv')

df

# %%
df_ob = pd.read_csv('observed.csv', index_col=0)
df_ob.index = pd.to_datetime(df_ob.index)
df_ob

# %%
#figure()でグラフを表示する領域をつくり，figというオブジェクトにする．figsize=(横,縦)
fig = plt.figure(figsize=(10, 5.5), dpi=120, facecolor='w')
#add_subplot()でグラフを描画する領域を追加する．引数は行，列，場所
ax1 = fig.add_subplot(2, 1, 1)
ax2 = fig.add_subplot(2, 1, 2)

ax1.set_xlim(datetime.datetime(2022, 1, 7, 14, 30, 00), datetime.datetime(2022, 4, 25, 00, 00, 00))
# ax1.set_ylim(-0.5, 0.2)
ax2.set_xlim(datetime.datetime(2022, 1, 7, 14, 30, 00), datetime.datetime(2022, 4, 25, 00, 00, 00))
# ax2.set_ylim(-15, 15)

ax1.plot(df.index, df["hi(stefan 0.68)"], c='black',linewidth=1.2)
# ax1.plot(df.index, df["hi(stefan)"], c='blue',linewidth=1.2)
# ax1.plot(df.index, df["hi(stefan)"], c='blue',linewidth=1.2)
ax1.scatter(df_ob.index, df_ob["hi (observed)"], c='#d70035')
# ax1.legend(["Stefan 係数調整 (cm)","Stefan 係数調整なし (cm)","実測値 (cm)"], prop={"family":"MS Gothic"})
ax1.legend(["計算値 (cm)","実測値 (cm)"], prop={"family":"MS Gothic"})
#ax1.set_title('temperature')
#ax1.set_xlabel('')
ax1.set_ylabel('Ice thickness (cm)',fontname = "Arial")

ax2.plot(df.index, df["U1-1[C]"], c='#d70035',linewidth=0.7)
ax2.plot(df.index, df["U1-11[C]"], c='black',linewidth=0.7)
ax2.plot(df.index, df["U1-13[C]"], c='#0000ff',linewidth=0.7)
ax2.plot(df.index, df["U1-14[C]"], c='#00885a',linewidth=0.7)
ax2.plot(df.index, df["U1-15[C]"], c='#8a2be2',linewidth=0.7)
ax2.legend(["U1-1[C]","U1-11[C]","U1-13[C]","U1-14[C]","U1-15[C]"],ncol=1)
#ax2.set_title('temperature')
#ax2.set_xlabel('')
ax2.set_ylabel('Temperature (°C)',fontname = "Arial")

name = "20220215_2段"

# 軸目盛の設定
ax1.xaxis.set_major_locator(mdates.DayLocator(bymonthday=None, interval=15, tz=None))
ax1.xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m-%d"))
ax2.xaxis.set_major_locator(mdates.DayLocator(bymonthday=None, interval=15, tz=None))
ax2.xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m-%d"))

plt.savefig(f'graph/{name}.png')
plt.savefig(f'graph/{name}.svg')
subprocess.call(f'inkscape graph/{name}.svg -M graph/{name}.emf', shell=True)

plt.show()

# %%
#figure()でグラフを表示する領域をつくり，figというオブジェクトにする．figsize=(横,縦)
fig = plt.figure(figsize=(10, 5.5), dpi=120, facecolor='w')
#add_subplot()でグラフを描画する領域を追加する．引数は行，列，場所
ax1 = fig.add_subplot(2, 1, 1)
ax2 = fig.add_subplot(2, 1, 2)

ax1.set_xlim(datetime.datetime(2022, 4, 21, 1, 30, 00), datetime.datetime(2022, 4, 28, 00, 00, 00))
# ax1.set_ylim(-0.5, 0.2)
ax2.set_xlim(datetime.datetime(2022, 4, 21, 1, 30, 00), datetime.datetime(2022, 4, 28, 00, 00, 00))
# ax2.set_ylim(-15, 15)

ax1.plot(df.index, df["hi(stefan 0.68)"], c='black',linewidth=1.2)
# ax1.plot(df.index, df["hi(stefan)"], c='blue',linewidth=1.2)
# ax1.plot(df.index, df["hi(stefan)"], c='blue',linewidth=1.2)
ax1.scatter(df_ob.index, df_ob["hi (observed)"], c='#d70035')
# ax1.legend(["Stefan 係数調整 (cm)","Stefan 係数調整なし (cm)","実測値 (cm)"], prop={"family":"MS Gothic"})
ax1.legend(["計算値 (cm)","実測値 (cm)"], prop={"family":"MS Gothic"})
#ax1.set_title('temperature')
#ax1.set_xlabel('')
ax1.set_ylabel('Ice thickness (cm)',fontname = "Arial")

ax2.plot(df.index, df["U1-1[C]"], c='#d70035',linewidth=0.7)
ax2.plot(df.index, df["U1-11[C]"], c='black',linewidth=0.7)
ax2.plot(df.index, df["U1-13[C]"], c='#0000ff',linewidth=0.7)
ax2.plot(df.index, df["U1-14[C]"], c='#00885a',linewidth=0.7)
ax2.plot(df.index, df["U1-15[C]"], c='#8a2be2',linewidth=0.7)
# ax2.legend(["U1-1[C]","U1-11[C]","U1-13[C]","U1-14[C]","U1-15[C]"],ncol=1)
#ax2.set_title('temperature')
#ax2.set_xlabel('')
ax2.set_ylabel('Temperature (°C)',fontname = "Arial")

name = "20220215_2段"

# 軸目盛の設定
ax1.xaxis.set_major_locator(mdates.DayLocator(bymonthday=None, interval=1, tz=None))
ax1.xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m-%d"))
ax2.xaxis.set_major_locator(mdates.DayLocator(bymonthday=None, interval=1, tz=None))
ax2.xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m-%d"))

plt.savefig(f'graph/{name}.png')
plt.savefig(f'graph/{name}.svg')
subprocess.call(f'inkscape graph/{name}.svg -M graph/{name}.emf', shell=True)

plt.show()

# %%
# df.to_csv('output/20220204.csv')
